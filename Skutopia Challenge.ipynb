# %%
import pandas as pd
import requests
import json

# %%
url = "https://api.worldbank.org/v2/country/all/indicator/NY.GDP.MKTP.CD?format=json&page=3"

# %%
response = requests.get(url)

# %%
print(response.status_code)
# Out:
# 200

# %%
res_json=response.json()

# %%
res_json
# Out:
# [{'page': 3,
#   'pages': 336,
#   'per_page': 50,
#   'total': 16758,
#   'sourceid': '2',
#   'lastupdated': '2023-12-18'},
#  [{'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1985',
#    'value': 116508527443.662,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1984',
#    'value': 114263904328.182,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1983',
#    'value': 138116898441.305,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
# ...

# %%
print(response.json())
# Out:
# [{'page': 1, 'pages': 336, 'per_page': 50, 'total': 16758, 'sourceid': '2', 'lastupdated': '2023-12-18'}, [{'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'}, 'countryiso3code': 'AFE', 'date': '2022', 'value': 1185137703650.99, 'unit': '', 'obs_status': '', 'decimal': 0}, {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'}, 'countryiso3code': 'AFE', 'date': '2021', 'value': 1086530704900.5, 'unit': '', 'obs_status': '', 'decimal': 0}, {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'}, 'countryiso3code': 'AFE', 'date': '2020', 'value': 928880235176.594, 'unit': '', 'obs_status': '', 'decimal': 0}, {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'}, 'countryis
# ...

# %%
print(pd.DataFrame(res_json))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 print(pd.DataFrame(res_json))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:745, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     743     if columns is not None:
#     744         columns = ensure_index(columns)
# --> 745     arrays, columns, index = nested_data_to_arrays(
#     746         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     747         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#     748         data,
#     749         columns,
#     750         index,  # type: ignore[arg-type]
#     751         dtype,
#     752     )
#     753     mgr = arrays_to_mgr(
#     754         arrays,
#     755         columns,
#    (...)
#     758         typ=manager,
#     759     )
#     760 else:
#
# ...

# %%
data = [json.dumps(row) for row in res_json]
df = pd.DataFrame(data)

# %%
res_json[1]
# Out:
# [{'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#   'countryiso3code': 'AFW',
#   'date': '1985',
#   'value': 116508527443.662,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#   'countryiso3code': 'AFW',
#   'date': '1984',
#   'value': 114263904328.182,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#   'countryiso3code': 'AFW',
#   'date': '1983',
#   'value': 138116898441.305,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
# ...

# %%
df=pd.DataFrame(res_json[1])

# %%
df.head()
# Out:
#                                            indicator  \
# 0  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 1  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 2  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 3  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 4  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
#
#                                              country countryiso3code  date  \
# 0  {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE  2022
# 1  {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE  2021
# 2  {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE  2020
# 3  {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE  2019
# 4  {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE  2018
#
#           value unit obs_status  decimal
# 0  1.185138e+12                        0
# 1  1.086531e+12                        0
# 2  9.288802e+11                        0
# ...

# %%
df.dtypes
# Out:
# indicator           object
# country             object
# countryiso3code     object
# date                object
# value              float64
# unit                object
# obs_status          object
# decimal              int64
# dtype: object

# %%
df.countryiso3code
# Out:
# 0     AFE
# 1     AFE
# 2     AFE
# 3     AFE
# 4     AFE
# 5     AFE
# 6     AFE
# 7     AFE
# 8     AFE
# 9     AFE
# 10    AFE
# 11    AFE
# 12    AFE
# 13    AFE
# 14    AFE
# 15    AFE
# 16    AFE
# 17    AFE
# 18    AFE
# 19    AFE
# 20    AFE
# 21    AFE
# 22    AFE
# 23    AFE
# 24    AFE
# 25    AFE
# 26    AFE
# 27    AFE
# 28    AFE
# 29    AFE
# 30    AFE
# 31    AFE
# 32    AFE
# 33    AFE
# 34    AFE
# 35    AFE
# 36    AFE
# 37    AFE
# 38    AFE
# 39    AFE
# 40    AFE
# 41    AFE
# 42    AFE
# 43    AFE
# 44    AFE
# 45    AFE
# 46    AFE
# 47    AFE
# 48    AFE
# 49    AFE
# Name: countryiso3code, dtype: object

# %%
df.indicator.['id']
# Out:
#   Cell In[91], line 1
#     df.indicator.['id']
#                  ^
# SyntaxError: invalid syntax

# %%
df.apply(lambda x: pd.Series(
    json.loads(x['indicator']).values(),
    index=json.loads(x['indicator']).keys()), 
    axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 df.apply(lambda x: pd.Series(
#       2     json.loads(x['indicator']).values(),
#       3     index=json.loads(x['indicator']).keys()),
#       4     axis=1)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:9565, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9554 from pandas.core.apply import frame_apply
#    9556 op = frame_apply(
#    9557     self,
#    9558     func=func,
#    (...)
#    9563     kwargs=kwargs,
#    9564 )
# -> 9565 return op.apply().__finalize__(self, method="apply")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:746, in FrameApply.apply(self)
#     743 elif self.raw:
#     744     return self.apply_raw()
# --> 746 return self.apply_standard()
#
# ...

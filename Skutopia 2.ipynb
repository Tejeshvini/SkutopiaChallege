# %%
## importing necessary modules
import requests
import pandas as pd

# %%
pip install wbgapi
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import requests
import json

# %%
## importing data from paginated API
total_results = []

# Loop through from pages 1 to 6
for page_num in range(1, 337):
    # Build the URL and download the results
    url = "https://api.worldbank.org/v2/country/all/indicator/NY.GDP.MKTP.CD?format=json&page=" + str(page_num)
    print("Downloading", url)
    response = requests.get(url)
    data = response.json()
    total_results = total_results + data[1]


print("We have", len(total_results), "total results")
# Out:
# ...
# We have 16758 total results

# %%
total_results[1]
# Out:
# {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#  'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#  'countryiso3code': 'AFE',
#  'date': '2021',
#  'value': 1086530704900.5,
#  'unit': '',
#  'obs_status': '',
#  'decimal': 0}

# %%
df=pd.DataFrame(total_results)

# %%
df
# Out:
#                                                indicator  \
# 0      {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 1      {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 2      {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 3      {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 4      {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# ...                                                  ...
# 16753  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 16754  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 16755  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 16756  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 16757  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
#
#                                                  country countryiso3code  \
# 0      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# 1      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# ...

# %%
df['country'][1]['value']
# Out:
# 'Africa Eastern and Southern'

# %%
df = df.rename(columns={'value': 'GDP'})

# %%
from pandas.io.json import json_normalize

# %%
## Normalising JSON columns to extrat data that is required
df1 = json_normalize(df['country'])
df2 = json_normalize(df['indicator'])
# Out:
# C:\Users\tejes\AppData\Local\Temp\ipykernel_27300\1915367803.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   df1 = json_normalize(df['country'])
# C:\Users\tejes\AppData\Local\Temp\ipykernel_27300\1915367803.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   df2 = json_normalize(df['indicator'])

# %%
df1.value.unique()
# Out:
# array(['Africa Eastern and Southern', 'Africa Western and Central',
#        'Arab World', 'Caribbean small states',
#        'Central Europe and the Baltics', 'Early-demographic dividend',
#        'East Asia & Pacific',
#        'East Asia & Pacific (excluding high income)',
#        'East Asia & Pacific (IDA & IBRD countries)', 'Euro area',
#        'Europe & Central Asia',
#        'Europe & Central Asia (excluding high income)',
#        'Europe & Central Asia (IDA & IBRD countries)', 'European Union',
#        'Fragile and conflict affected situations',
#        'Heavily indebted poor countries (HIPC)', 'High income',
#        'IBRD only', 'IDA & IBRD total', 'IDA blend', 'IDA only',
#        'IDA total', 'Late-demographic dividend',
#        'Latin America & Caribbean',
#        'Latin America & Caribbean (excluding high income)',
#        'Latin America & the Caribbean (IDA & IBRD countries)',
#        'Least developed countries: UN classification',
# ...

# %%
df1
# Out:
#        id                        value
# 0      ZH  Africa Eastern and Southern
# 1      ZH  Africa Eastern and Southern
# 2      ZH  Africa Eastern and Southern
# 3      ZH  Africa Eastern and Southern
# 4      ZH  Africa Eastern and Southern
# ...    ..                          ...
# 16753  ZW                     Zimbabwe
# 16754  ZW                     Zimbabwe
# 16755  ZW                     Zimbabwe
# 16756  ZW                     Zimbabwe
# 16757  ZW                     Zimbabwe
#
# [16758 rows x 2 columns]

# %%
df1 = df1.rename(columns={'id': 'country_code', 'value': 'Country'})

# %%
## Concatinating normalised results with orginal dataframe
df_final = pd.concat([df,df1], axis=1)

# %%
df_final
# Out:
#                                                indicator  \
# 0      {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 1      {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 2      {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 3      {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 4      {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# ...                                                  ...
# 16753  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 16754  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 16755  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 16756  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 16757  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
#
#                                                  country countryiso3code  \
# 0      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# 1      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# ...

# %%
## Taking country values only in the country column
countries = ['Afghanistan', 'Albania', 'Algeria', 'American Samoa',
       'Andorra', 'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia',
       'Aruba', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas, The',
       'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium',
       'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia',
       'Bosnia and Herzegovina', 'Botswana', 'Brazil',
       'British Virgin Islands', 'Brunei Darussalam', 'Bulgaria',
       'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon',
       'Canada', 'Cayman Islands', 'Central African Republic', 'Chad',
       'Channel Islands', 'Chile', 'China', 'Colombia', 'Comoros',
       'Congo, Dem. Rep.', 'Congo, Rep.', 'Costa Rica', "Cote d'Ivoire",
       'Croatia', 'Cuba', 'Curacao', 'Cyprus', 'Czechia', 'Denmark',
       'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador',
       'Egypt, Arab Rep.', 'El Salvador', 'Equatorial Guinea', 'Eritrea',
       'Estonia', 'Eswatini', 'Ethiopia', 'Faroe Islands', 'Fiji',
       'Finland', 'France', 'French Polynesia', 'Gabon', 'Gambia, The',
       'Georgia', 'Germany', 'Ghana', 'Gibraltar', 'Greece', 'Greenland',
       'Grenada', 'Guam', 'Guatemala', 'Guinea', 'Guinea-Bissau',
       'Guyana', 'Haiti', 'Honduras', 'Hong Kong SAR, China', 'Hungary',
       'Iceland', 'India', 'Indonesia', 'Iran, Islamic Rep.', 'Iraq',
       'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan',
       'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati',
       "Korea, Dem. People's Rep.", 'Korea, Rep.', 'Kosovo', 'Kuwait',
       'Kyrgyz Republic', 'Lao PDR', 'Latvia', 'Lebanon', 'Lesotho',
       'Liberia', 'Libya', 'Liechtenstein', 'Lithuania', 'Luxembourg',
       'Macao SAR, China', 'Madagascar', 'Malawi', 'Malaysia', 'Maldives',
       'Mali', 'Malta', 'Marshall Islands', 'Mauritania', 'Mauritius',
       'Mexico', 'Micronesia, Fed. Sts.', 'Moldova', 'Monaco', 'Mongolia',
       'Montenegro', 'Morocco', 'Mozambique', 'Myanmar', 'Namibia',
       'Nauru', 'Nepal', 'Netherlands', 'New Caledonia', 'New Zealand',
       'Nicaragua', 'Niger', 'Nigeria', 'North Macedonia',
       'Northern Mariana Islands', 'Norway', 'Oman', 'Pakistan', 'Palau',
       'Panama', 'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines',
       'Poland', 'Portugal', 'Puerto Rico', 'Qatar', 'Romania',
       'Russian Federation', 'Rwanda', 'Samoa', 'San Marino',
       'Sao Tome and Principe', 'Saudi Arabia', 'Senegal', 'Serbia',
       'Seychelles', 'Sierra Leone', 'Singapore',
       'Sint Maarten (Dutch part)', 'Slovak Republic', 'Slovenia',
       'Solomon Islands', 'Somalia', 'South Africa', 'South Sudan',
       'Spain', 'Sri Lanka', 'St. Kitts and Nevis', 'St. Lucia',
       'St. Martin (French part)', 'St. Vincent and the Grenadines',
       'Sudan', 'Suriname', 'Sweden', 'Switzerland',
       'Syrian Arab Republic', 'Tajikistan', 'Tanzania', 'Thailand',
       'Timor-Leste', 'Togo', 'Tonga', 'Trinidad and Tobago', 'Tunisia',
       'Turkiye', 'Turkmenistan', 'Turks and Caicos Islands', 'Tuvalu',
       'Uganda', 'Ukraine', 'United Arab Emirates', 'United Kingdom',
       'United States', 'Uruguay', 'Uzbekistan', 'Vanuatu',
       'Venezuela, RB', 'Viet Nam', 'Virgin Islands (U.S.)',
       'West Bank and Gaza', 'Yemen, Rep.', 'Zambia', 'Zimbabwe']

# %%
## Filtering group of country values from the country column
df_cleaned = df_final[df_final['Country'].isin(countries)]
# Out:
# C:\Users\tejes\AppData\Local\Temp\ipykernel_27300\4106750891.py:1: FutureWarning: reindexing with a non-unique Index is deprecated and will raise in a future version.
#   df_cleaned = df_final[df_final['Country'].isin(countries)]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[469], line 1
# ----> 1 df_cleaned = df_final[df_final['Country'].isin(countries)]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3792, in DataFrame.__getitem__(self, key)
#    3790 # Do we have a (boolean) DataFrame?
#    3791 if isinstance(key, DataFrame):
# -> 3792     return self.where(key)
#    3794 # Do we have a (boolean) 1d indexer?
#    3795 if com.is_bool_indexer(key):
#
# ...

# %%
df_cleaned
# Out:
#                                                indicator  \
# 3087   {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 3088   {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 3089   {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 3090   {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 3091   {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# ...                                                  ...
# 16753  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 16754  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 16755  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 16756  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 16757  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
#
#                                     country countryiso3code  date  \
# 3087   {'id': 'AF', 'value': 'Afghanistan'}             AFG  2022
# 3088   {'id': 'AF', 'value': 'Afghanistan'}             AFG  2021
# 3089   {'id': 'AF', 'value': 'Afghanistan'}             AFG  2020
# ...

# %%
df_cleaned.Country.unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas, The', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'British Virgin Islands',
#        'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi',
#        'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada', 'Cayman Islands',
#        'Central African Republic', 'Chad', 'Channel Islands', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Denmark', 'Djibouti', 'Dominica',
#        'Dominican Republic', 'Ecuador', 'Egypt, Arab Rep.', 'El Salvador',
# ...

# %%
len(df_cleaned.Country.unique())
# Out:
# 217

# %% [markdown]
# Connecting to postgres SQL database

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://postgres:ritu123@localhost:5432/gdp_worldbank')

# %%
engine
# Out:
# Engine(postgresql://postgres:***@localhost:5432/gdp_worldbank)

# %%
## importing neccesary modules to connect to Postgres database (hosted locally)
import psycopg2
import pandas.io.sql as sqlio

import psycopg2 
import numpy as np 
import psycopg2.extras as extras 
import pandas as pd

# %%
conn = psycopg2.connect(database = "gdp_worldbank", 
                        user = "postgres", 
                        host= 'localhost',
                        password = "ritu123",
                        port = 5432)

# %%
conn = psycopg2.connect("host=127.0.0.1 dbname=gdp_worldbank user=postgres password=ritu123")

# %%
import psycopg2

#Establishing the connection
conn = psycopg2.connect(database = "gdp_worldbank", 
                        user = "postgres", 
                        host= 'localhost',
                        password = "ritu123",
                        port = 5432)
#Creating a cursor object using the cursor() method
cursor = conn.cursor()

#Doping EMPLOYEE table if already exists.
cursor.execute("DROP TABLE IF EXISTS gdp_data")

#Creating gdp data table as per requirement
sql ='''CREATE TABLE gdp_data(
   ID TEXT PRIMARY KEY     NOT NULL,
   Country           TEXT    NOT NULL,
   Country_Code      TEXT    NOT NULL,
   DATE        INT    NOT NULL,
   GDP         FLOAT
)'''
cursor.execute(sql)
print("Table created successfully........")
conn.commit()
#Closing the connection
# conn.close()
# Out:
# Table created successfully........

# %%
cursor.execute("DROP TABLE IF EXISTS gdp_data2")

sql=""" SELECT * FROM pg_catalog.pg_tables """

# %%
sqlio.read_sql_query(sql,conn)
# Out:
# C:\Users\tejes\AppData\Local\Temp\ipykernel_27300\1894918143.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sqlio.read_sql_query(sql,conn)
#             schemaname                tablename tableowner tablespace  \
# 0           pg_catalog             pg_statistic   postgres       None
# 1           pg_catalog                  pg_type   postgres       None
# 2           pg_catalog         pg_foreign_table   postgres       None
# 3           pg_catalog                pg_authid   postgres  pg_global
# 4               public                 gdp_data   postgres       None
# ..                 ...                      ...        ...        ...
# 64          pg_catalog           pg_largeobject   postgres       None
# 65  information_schema             sql_features   postgres       None
# ...

# %%
sqlio.read_sql_query(sql,conn)
# Out:
# C:\Users\tejes\AppData\Local\Temp\ipykernel_27300\1894918143.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sqlio.read_sql_query(sql,conn)
#             schemaname                tablename tableowner tablespace  \
# 0           pg_catalog             pg_statistic   postgres       None
# 1           pg_catalog                  pg_type   postgres       None
# 2           pg_catalog         pg_foreign_table   postgres       None
# 3           pg_catalog                pg_authid   postgres  pg_global
# 4               public                 gdp_data   postgres       None
# ..                 ...                      ...        ...        ...
# 64          pg_catalog           pg_largeobject   postgres       None
# 65  information_schema             sql_features   postgres       None
# ...

# %%
df_cleaned.head()
# Out:
#                                               indicator  \
# 3087  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 3088  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 3089  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 3090  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 3091  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
#
#                                    country countryiso3code  date         GDP  \
# 3087  {'id': 'AF', 'value': 'Afghanistan'}             AFG  2022         NaN
# 3088  {'id': 'AF', 'value': 'Afghanistan'}             AFG  2021 14266499430
# 3089  {'id': 'AF', 'value': 'Afghanistan'}             AFG  2020 19955929061
# 3090  {'id': 'AF', 'value': 'Afghanistan'}             AFG  2019 18799444415
# 3091  {'id': 'AF', 'value': 'Afghanistan'}             AFG  2018 18053222735
#
#      unit obs_status  decimal country_code      Country        id
# 3087                        0           AF  Afghanistan  AFG_2022
# ...

# %%
df_cleaned['id'] = df_cleaned['countryiso3code'] + '_' + df_cleaned['date']
# Out:
# C:\Users\tejes\AppData\Local\Temp\ipykernel_27300\4294325743.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['id'] = df_cleaned['countryiso3code'] + '_' + df_cleaned['date']

# %%
df_cleaned.head()
# Out:
#                                               indicator  \
# 3087  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 3088  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 3089  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 3090  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 3091  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
#
#                                    country countryiso3code  date         GDP  \
# 3087  {'id': 'AF', 'value': 'Afghanistan'}             AFG  2022         NaN
# 3088  {'id': 'AF', 'value': 'Afghanistan'}             AFG  2021 14266499430
# 3089  {'id': 'AF', 'value': 'Afghanistan'}             AFG  2020 19955929061
# 3090  {'id': 'AF', 'value': 'Afghanistan'}             AFG  2019 18799444415
# 3091  {'id': 'AF', 'value': 'Afghanistan'}             AFG  2018 18053222735
#
#      unit obs_status  decimal country_code      Country        id
# 3087                        0           AF  Afghanistan  AFG_2022
# ...

# %%
df_cleaned.head()
# Out:
#                                               indicator  \
# 3087  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 3088  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 3089  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 3090  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 3091  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
#
#                                    country countryiso3code  date         GDP  \
# 3087  {'id': 'AF', 'value': 'Afghanistan'}             AFG  2022         NaN
# 3088  {'id': 'AF', 'value': 'Afghanistan'}             AFG  2021 14266499430
# 3089  {'id': 'AF', 'value': 'Afghanistan'}             AFG  2020 19955929061
# 3090  {'id': 'AF', 'value': 'Afghanistan'}             AFG  2019 18799444415
# 3091  {'id': 'AF', 'value': 'Afghanistan'}             AFG  2018 18053222735
#
#      unit obs_status  decimal country_code      Country        id
# 3087                        0           AF  Afghanistan  AFG_2022
# ...

# %%
## Retaining columns required in the tasks
df_cleaned_final = df_cleaned[['id','Country','country_code','date','GDP']]

# %%
len(df_cleaned_final)
# Out:
# 13671

# %%
## Insert the data extracted from the API into the postgres database
def execute_values(conn, df, table): 
  
    tuples = [tuple(x) for x in df.to_numpy()] 
  
    cols = ','.join(list(df.columns)) 
    # SQL query to execute 
    query = "INSERT INTO %s(%s) VALUES %%s" % (table, cols) 
    cursor = conn.cursor() 
    try: 
        extras.execute_values(cursor, query, tuples) 
        conn.commit() 
    except (Exception, psycopg2.DatabaseError) as error: 
        print("Error: %s" % error) 
        conn.rollback() 
        cursor.close() 
        return 1
    print("the dataframe is inserted") 
    cursor.close()

# %%
execute_values(conn, df_cleaned_final, 'gdp_data')
# Out:
# the dataframe is inserted

# %%
import psycopg2

#Establishing the connection
conn = psycopg2.connect(database = "gdp_worldbank", 
                        user = "postgres", 
                        host= 'localhost',
                        password = "ritu123",
                        port = 5432)
#Creating a cursor object using the cursor() method
cursor = conn.cursor()

#Creating table as per requirement
sql ='''select * from gdp_data'''
cursor.execute(sql)
conn.commit()
#Closing the connection
# conn.close()

# %%
sqlio.read_sql_query(sql,conn)
# Out:
# C:\Users\tejes\AppData\Local\Temp\ipykernel_27300\1894918143.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sqlio.read_sql_query(sql,conn)
#              id      country country_code  date                  gdp
# 0      AFG_2022  Afghanistan           AF  2022                  NaN
# 1      AFG_2021  Afghanistan           AF  2021 $14,266,499,429.8746
# 2      AFG_2020  Afghanistan           AF  2020 $19,955,929,060.8410
# 3      AFG_2019  Afghanistan           AF  2019 $18,799,444,414.5998
# 4      AFG_2018  Afghanistan           AF  2018 $18,053,222,734.8881
# ...         ...          ...          ...   ...                  ...
# 13666  ZWE_1964     Zimbabwe           ZW  1964  $1,217,138,000.0000
# 13667  ZWE_1963     Zimbabwe           ZW  1963  $1,159,511,700.0000
# ...

# %%
import psycopg2

#Establishing the connection
conn = psycopg2.connect(database = "gdp_worldbank", 
                        user = "postgres", 
                        host= 'localhost',
                        password = "ritu123",
                        port = 5432)
#Creating a cursor object using the cursor() method
cursor = conn.cursor()


#Executing query with gdp_growth column
sql ='''SELECT  country,
        date as year,
        GDP,
        (GDP-LAG (GDP,1) OVER (PARTITION BY country ORDER BY date ASC))
        /(LAG (GDP,1) OVER (PARTITION BY country ORDER BY date ASC)) AS gdp_growth
FROM gdp_data where date >= 2000'''
cursor.execute(sql)
conn.commit()
#Closing the connection
# conn.close()

# %%
x = sqlio.read_sql_query(sql,conn)
# Out:
# C:\Users\tejes\AppData\Local\Temp\ipykernel_27300\2377383264.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   x = sqlio.read_sql_query(sql,conn)

# %%
xa = x.dropna(subset=["gdp"])

# %%
xa
# Out:
#           country  year                 gdp  gdp_growth
# 2     Afghanistan  2002  3,825,701,405.5196         NaN
# 3     Afghanistan  2003  4,520,946,849.3208      0.1817
# 4     Afghanistan  2004  5,224,896,718.6778      0.1557
# 5     Afghanistan  2005  6,203,256,497.0904      0.1872
# 6     Afghanistan  2006  6,971,758,332.8892      0.1239
# ...           ...   ...                 ...         ...
# 4986     Zimbabwe  2018 34,156,069,918.0609      0.9424
# 4987     Zimbabwe  2019 21,832,234,921.1762     -0.3608
# 4988     Zimbabwe  2020 21,509,698,406.6618     -0.0148
# 4989     Zimbabwe  2021 28,371,238,665.8646      0.3190
# 4990     Zimbabwe  2022 27,366,627,153.0852     -0.0354
#
# [4770 rows x 4 columns]

# %%
xa["min_gdp_growth_since_2000"] = xa["gdp_growth"].min()
xa["max_gdp_growth_since_2000"] = xa["gdp_growth"].max()
# Out:
# C:\Users\tejes\AppData\Local\Temp\ipykernel_27300\3290619133.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   xa["min_gdp_growth_since_2000"] = xa["gdp_growth"].min()
# C:\Users\tejes\AppData\Local\Temp\ipykernel_27300\3290619133.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   xa["max_gdp_growth_since_2000"] = xa["gdp_growth"].max()

# %%
xa
# Out:
#           country  year                 gdp  gdp_growth  \
# 2     Afghanistan  2002  3,825,701,405.5196         NaN
# 3     Afghanistan  2003  4,520,946,849.3208      0.1817
# 4     Afghanistan  2004  5,224,896,718.6778      0.1557
# 5     Afghanistan  2005  6,203,256,497.0904      0.1872
# 6     Afghanistan  2006  6,971,758,332.8892      0.1239
# ...           ...   ...                 ...         ...
# 4986     Zimbabwe  2018 34,156,069,918.0609      0.9424
# 4987     Zimbabwe  2019 21,832,234,921.1762     -0.3608
# 4988     Zimbabwe  2020 21,509,698,406.6618     -0.0148
# 4989     Zimbabwe  2021 28,371,238,665.8646      0.3190
# 4990     Zimbabwe  2022 27,366,627,153.0852     -0.0354
#
#       min_gdp_growth_since_2000  max_gdp_growth_since_2000
# 2                       -0.7507                     4.0788
# 3                       -0.7507                     4.0788
# 4                       -0.7507                     4.0788
# ...

# %%
pd.options.display.float_format = '{:,.4f}'.format

# %%
1692956646856/1559033756285 - 1
# Out:
# 0.08590121287054298

# %%
y['max_gdp_growth_since_2000'].unique()
# Out:
# array([nan])

# %%
y.loc[x['country'] == "Australia"]
# Out:
#                     country  date                 gdp  gdp_growth  \
# 630  British Virgin Islands  2009                 NaN         NaN
# 631  British Virgin Islands  2010                 NaN         NaN
# 632  British Virgin Islands  2011                 NaN         NaN
# 633  British Virgin Islands  2012                 NaN         NaN
# 634  British Virgin Islands  2013                 NaN         NaN
# ..                      ...   ...                 ...         ...
# 688                Bulgaria  2021 84,041,493,015.6618      0.1943
# 689                Bulgaria  2022 90,346,169,914.9349      0.0750
# 690            Burkina Faso  2000  2,968,370,087.5976         NaN
# 691            Burkina Faso  2001  3,190,371,080.9477      0.0748
# 692            Burkina Faso  2002  3,622,350,062.9605      0.1354
#
#      min_gdp_growth_since_2000  max_gdp_growth_since_2000
# 630                    -0.7507                        NaN
# ...

# %% [markdown]
# Visualisation challenge

# %%
online_retail = pd.read_csv(r"C:\Users\tejes\Downloads\Online Retail.csv")

# %%
cancels = online_retail[online_retail['InvoiceNo'].str.contains("C")]

# %%
def ranked(x):
    x['Revenue'] = x['Quantity'].abs()*x['UnitPrice']
    x_grouped = pd.DataFrame(x.groupby('Description')['Revenue'].sum()).reset_index()
    x_grouped['Rank']=x_grouped['Revenue'].rank(ascending=False)
    return(x_grouped.sort_values(by=['Rank']))

# %%
cancels_grouped_ranked = ranked(cancels)
all_grouped_ranked = ranked(online_retail)
# Out:
# C:\Users\tejes\AppData\Local\Temp\ipykernel_27300\3253213110.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['Revenue'] = x['Quantity'].abs()*x['UnitPrice']

# %%
cancels_grouped_ranked.to_csv("Cancels_grouped_ranked.csv")
all_grouped_ranked.to_csv("All_grouped_ranked.csv")

# %%
cancels_grouped['Rank']=cancels_grouped['Revenue'].rank(ascending=False)

# %%
cancels_grouped
# Out:
#                            Description  Revenue       Rank
# 0        50'S CHRISTMAS GIFT BAG LARGE   2.5000 1,821.0000
# 1                    DOLLY GIRL BEAKER   8.7500 1,505.0000
# 2           OVAL WALL MIRROR DIAMANTE   49.7500   691.0000
# 3      SET 2 TEA TOWELS I LOVE LONDON   25.4000   982.0000
# 4               SPACEBOY BABY GIFT SET 101.7000   432.0000
# ...                                ...      ...        ...
# 1967  ZINC SWEETHEART WIRE LETTER RACK  15.0000 1,266.0000
# 1968    ZINC T-LIGHT HOLDER STAR LARGE  10.4500 1,436.0000
# 1969   ZINC T-LIGHT HOLDER STARS SMALL  36.5200   816.0000
# 1970    ZINC TOP  2 DOOR WOODEN SHELF   76.7500   517.0000
# 1971  ZINC WILLIE WINKIE  CANDLE STICK  10.2000 1,450.5000
#
# [1972 rows x 3 columns]

# %%
cancels_grouped.sort_values(by=['Rank'])
# Out:
#                              Description      Revenue       Rank
# 79                            AMAZON FEE 235,281.5900     1.0000
# 1184         PAPER CRAFT , LITTLE BIRDIE 168,469.6000     2.0000
# 1093                              Manual 146,784.4600     3.0000
# 1025      MEDIUM CERAMIC TOP STORAGE JAR  77,479.6400     4.0000
# 1305                             POSTAGE  11,871.2400     5.0000
# ...                                  ...          ...        ...
# 1719            STRIPY DESIGN SHOWER CAP       0.2900 1,968.5000
# 681         FRENCH STYLE STORAGE JAR JAM       0.2900 1,968.5000
# 1334  RECYCLED PENCIL WITH RABBIT ERASER       0.2100 1,970.0000
# 1702                    STARS GIFT TAPE        0.1900 1,971.0000
# 800         HANGING WOOD AND FELT FLOWER       0.1200 1,972.0000
#
# [1972 rows x 3 columns]

# %%
cancels_grouped.to_csv("Online_retail_cancels.csv")

# %%
online_retail
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
online_retail['Quantity'] = online_retail['Quantity'].abs()

# %%
    online_retail['Revenue'] = online_retail['Quantity'].abs()*online_retail['UnitPrice']
    online_retail_grouped = pd.DataFrame(online_retail.groupby('Description')['Revenue'].sum()).reset_index()
    online_retail_grouped['Rank']=online_retail_grouped['Revenue'].rank(ascending=False)
    online_retail_grouped.sort_values(by=['Rank'])
# Out:
#                               Description      Revenue       Rank
# 2445          PAPER CRAFT , LITTLE BIRDIE 336,939.2000     1.0000
# 171                            AMAZON FEE 249,042.6800     2.0000
# 2246                               Manual 224,897.2800     3.0000
# 1098                       DOTCOM POSTAGE 206,252.0600     4.0000
# 2915             REGENCY CAKESTAND 3 TIER 184,207.2900     5.0000
# ...                                   ...          ...        ...
# 4104  add stock to allocate online orders       0.0000 4,132.0000
# 4105                               adjust       0.0000 4,132.0000
# 2247                      Marked as 23343       0.0000 4,132.0000
# 4222                    wrongly sold sets       0.0000 4,132.0000
# 281                       Adjust bad debt -11,062.0600 4,223.0000
#
# [4223 rows x 3 columns]

# %%
online_retail[online_retail['Description']== "Adjust bad debt"]
# Out:
#        InvoiceNo StockCode      Description  Quantity    InvoiceDate  \
# 299982   A563185         B  Adjust bad debt         1  8/12/11 14:50
# 299983   A563186         B  Adjust bad debt         1  8/12/11 14:51
# 299984   A563187         B  Adjust bad debt         1  8/12/11 14:52
#
#           UnitPrice  CustomerID         Country      Revenue
# 299982  11,062.0600         NaN  United Kingdom  11,062.0600
# 299983 -11,062.0600         NaN  United Kingdom -11,062.0600
# 299984 -11,062.0600         NaN  United Kingdom -11,062.0600
